# %%
for i in range(1,2001):
    print('I love you.')
# Out:
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# I love you.
# ...

# %%
with open('hu.txt','w') as h:
    h.write('Hahahahah')

# %%
with open('hu.txt','r') as h:
    a= h.read()

# %%
a
# Out:
# 'Hahahahah'

# %%
with open('hu.txt','a') as h:
    for i
# Out:
#   File "<ipython-input-1-d38b594b743e>", line 2
#     for i
#          ^
# SyntaxError: invalid syntax

# %%
import t

# %%
t.add(5,3)
# Out:
# 15

# %%
t.sub(2,1)
# Out:
# 2

# %%
t.mul(3,5)
# Out:
# 'Ye kia hy?'
